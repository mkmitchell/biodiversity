# %%
import papermill as pm
import duckdb, subprocess, os, time
from joblib import Parallel, delayed

# %%
species_list = [
    "Protonotaria citrea",
    "Limnothlypis swainsonii",
    "Setophaga americana",
    "Empidonax virescens",
    "Coccyzus americanus",
    "Vireo griseus",
    "Setophaga cerulea",
    "Hylocichla mustelina",
    "Parkesia motacilla",
    "Geothlypis formosa",
    "Archilochus colubris",
    "Elanoides forficatus",
    "Vireo flavifrons",
    "Buteo lineatus",
    "Setophaga dominica",
    "Setophaga citrina",
    "Dryocopus pileatus",
    "Meleagris gallopavo",
    "Sphyrapicus varius",
    "Odocoileus virginianus",     # white tailed deer
    "Ursus americanus",           # Black bear
    "Anaxyrus americanus",        # American Toad
    "Anaxyrus fowleri",           # Fowler's Toad
    "Gastrophryne carolinensis",  # Eastern Narrow-mouthed Toad
    "Hyla avivoca",               # Bird-voiced Treefrog
    "Hyla chrysoscelis",          # Cope's Gray Treefrog
    "Hyla cinerea",               # Green Treefrog
    "Hyla squirella",             # Squirrel Treefrog    
    "Hyla versicolor",            # Gray Treefrog
    "Lithobates catesbeianus",    # American Bullfrog
    "Lithobates clamitans",       # Bronze Frog
    "Lithobates palustris",       # Pickerel Frog
    "Lithobates sphenocephalus",  # Southern Leopard Frog
    "Pseudacris crucifer",        # Spring Peeper
    "Pseudacris fouquettei",      # Cajun Chorus Frog
    "Kinosternon subrubrum",      # Eastern Mud Turtle
    "Apalone spinifera",          # Spiny Softshell Turtle   
    "Macrochelys temmincki"       # Alligator Snapping Turtle    
    ]
basedir = '/mnt/f/readyparams'
outputdir = '/mnt/f/readyparams/ppp_paramsoutput'
jobs = 10
tplist = ['winter', 'summer', 'fall', 'spring']
os.makedirs(outputdir, exist_ok=True)

# %%
species_list = [s.replace(" ", "_").lower() for s in species_list]
def f(x):
    try:
        spoutputdir = os.path.join(outputdir,x)
        os.makedirs(spoutputdir, exist_ok=True)        
        print('run',x)
        if jobs >1:
            for tp in tplist:
                subprocess.run(pm.execute_notebook(f'maxent_inference.ipynb',os.path.join(spoutputdir,f'{x}_{tp}_infer.ipynb'),parameters=dict(basedir=basedir, tp=tp, sp=x)), shell=True)
        else:
            for tp in tplist:
                pm.execute_notebook(f'maxent_inference.ipynb',os.path.join(spoutputdir,f'{x}_{tp}_infer.ipynb'),parameters=dict(basedir=basedir, tp=tp, sp=x))
        return (x, tp, 'run complete')
    except Exception as e:
        return (x, tp, 'fail', e)

# %%
completed = Parallel(n_jobs=10, verbose=0)(delayed(f)(species_list[x]) for x in range(len(species_list)))
# Out:
# run setophaga_cerulea
# run hylocichla_mustelina
# run coccyzus_americanus
# run geothlypis_formosa
# run parkesia_motacilla
# run vireo_griseus
# run limnothlypis_swainsonii
# run empidonax_virescens
# run setophaga_americana
# run protonotaria_citrea
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.27s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.30s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.29s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:24<00:00,  9.36s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:24<00:00,  9.40s/cell]
# Executing: 100%|██████████| 9/9 [01:24<00:00,  9.39s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:25<00:00,  9.47s/cell]
# Executing: 100%|██████████| 9/9 [01:25<00:00,  9.47s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:25<00:00,  9.51s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:25<00:00,  9.53s/cell]
# Executing:  67%|██████▋   | 6/9 [00:01<00:00,  6.58cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.13s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.11s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:21<00:00,  9.07s/cell]
# Executing:  11%|█         | 1/9 [00:01<00:09,  1.19s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.29s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.23s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.30s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.13s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.22s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.15s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.18s/cell]
# metadata: 1: cells: not found
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.30cell/s]
# Executing:  11%|█         | 1/9 [00:00<00:07,  1.10cell/s]
# run archilochus_colubris
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.29cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.45cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]1cell/s]
# run elanoides_forficatus
# run vireo_flavifrons
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.41cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.37cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# run buteo_lineatus
# run setophaga_dominica
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.52cell/s]
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.26cell/s]
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.25cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# run setophaga_citrina
# run dryocopus_pileatus
# run meleagris_gallopavo
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.54cell/s]
# Executing:  11%|█         | 1/9 [00:00<00:07,  1.02cell/s]
# run sphyrapicus_varius
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.35cell/s]
# Executing:  11%|█         | 1/9 [00:01<00:08,  1.04s/cell]
# run odocoileus_virginianus
# Executing: 100%|██████████| 9/9 [01:21<00:00,  9.02s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.22s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.19s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.28s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.20s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.25s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.25s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.22s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.15s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.30s/cell]
# Executing:  11%|█         | 1/9 [00:00<00:07,  1.09cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:20<00:00,  8.96s/cell]
# metadata: 1: cells: not found
# Executing:  78%|███████▊  | 7/9 [00:03<00:01,  1.98cell/s]
# Executing:  78%|███████▊  | 7/9 [01:21<00:24, 12.11s/cell]
# run ursus_americanus
# Executing: 100%|██████████| 9/9 [01:22<00:00,  9.14s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.31s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.32s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.32s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.33s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.33s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.32s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.30s/cell]
# Executing: 100%|██████████| 9/9 [01:23<00:00,  9.24s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.45cell/s]
# Executing:  11%|█         | 1/9 [00:00<00:07,  1.05cell/s]
# run anaxyrus_americanus
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.43cell/s]
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.32cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# run anaxyrus_fowleri
# run gastrophryne_carolinensis
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.25cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.42cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.44cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.44cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# run hyla_avivoca
# run hyla_chrysoscelis
# run hyla_cinerea
# run hyla_squirella
# Executing:  78%|███████▊  | 7/9 [00:03<00:00,  2.26cell/s]
# Executing:  78%|███████▊  | 7/9 [00:02<00:00,  2.36cell/s]
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# run hyla_versicolor
# run lithobates_catesbeianus
# Executing:  67%|██████▋   | 6/9 [00:01<00:00,  6.92cell/s]

# %%
print('## Failed species ##')
print('')
for i, result in enumerate(completed):
    if result[1] == 'fail':
        print(result[0], result[1])
