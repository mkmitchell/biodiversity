# %%
import papermill as pm
import duckdb, subprocess, os, time
from joblib import Parallel, delayed

# %%
species_list = [
    "Protonotaria citrea",
    "Limnothlypis swainsonii",
    "Setophaga americana",
    "Empidonax virescens",
    "Coccyzus americanus",
    "Vireo griseus",
    "Setophaga cerulea",
    "Hylocichla mustelina",
    "Parkesia motacilla",
    "Geothlypis formosa",
    "Archilochus colubris",
    "Elanoides forficatus",
    "Vireo flavifrons",
    "Buteo lineatus",
    "Setophaga dominica",
    "Setophaga citrina",
    "Dryocopus pileatus",
    "Meleagris gallopavo",
    "Sphyrapicus varius",
    "Odocoileus virginianus",     # white tailed deer
    "Ursus americanus",           # Black bear
    "Anaxyrus americanus",        # American Toad
    "Anaxyrus fowleri",           # Fowler's Toad
    "Gastrophryne carolinensis",  # Eastern Narrow-mouthed Toad
    "Hyla avivoca",               # Bird-voiced Treefrog
    "Hyla chrysoscelis",          # Cope's Gray Treefrog
    "Hyla cinerea",               # Green Treefrog
    "Hyla squirella",             # Squirrel Treefrog    
    "Hyla versicolor",            # Gray Treefrog
    "Lithobates catesbeianus",    # American Bullfrog
    "Lithobates clamitans",       # Bronze Frog
    "Lithobates palustris",       # Pickerel Frog
    "Lithobates sphenocephalus",  # Southern Leopard Frog
    "Pseudacris crucifer",        # Spring Peeper
    "Pseudacris fouquettei",      # Cajun Chorus Frog
    "Kinosternon subrubrum",      # Eastern Mud Turtle
    "Apalone spinifera",          # Spiny Softshell Turtle   
    "Macrochelys temmincki"       # Alligator Snapping Turtle    
    ]
basedir = '/mnt/f/readyparams'
outputdir = '/mnt/f/readyparams/ppp_paramsoutput'
jobs = 10
tplist = ['winter', 'summer', 'fall', 'spring']
os.makedirs(outputdir, exist_ok=True)

# %%
species_list = [s.replace(" ", "_").lower() for s in species_list]
def f(x):
    try:
        spoutputdir = os.path.join(outputdir,x)
        os.makedirs(spoutputdir, exist_ok=True)        
        print('run',x)
        if jobs >1:
            for tp in tplist:
                subprocess.run(pm.execute_notebook(f'maxent_inference.ipynb',os.path.join(spoutputdir,f'{x}_{tp}_infer.ipynb'),parameters=dict(basedir=basedir, tp=tp, sp=x)), shell=True)
        else:
            for tp in tplist:
                pm.execute_notebook(f'maxent_inference.ipynb',os.path.join(spoutputdir,f'{x}_{tp}_infer.ipynb'),parameters=dict(basedir=basedir, tp=tp, sp=x))
        return (x, tp, 'run complete')
    except Exception as e:
        return (x, tp, 'fail', e)

# %%
completed = Parallel(n_jobs=10, verbose=0)(delayed(f)(species_list[x]) for x in range(len(species_list)))
# Out:
# run setophaga_americana
# run parkesia_motacilla
# run geothlypis_formosa
# run coccyzus_americanus
# run protonotaria_citrea
# run hylocichla_mustelina
# run vireo_griseus
# run setophaga_cerulea
# run limnothlypis_swainsonii
# run empidonax_virescens
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.06s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.07s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.08s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.08s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.08s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.09s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.07s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.08s/cell]
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.09s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:28<00:00, 11.07s/cell]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.28s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.31s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.37s/cell]
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.37s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.38s/cell]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.39s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.42s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.42s/cell]
# Executing:  75%|███████▌  | 6/8 [00:01<00:00,  6.10cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.43s/cell]
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.44s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.22s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.17s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.13s/cell]
# Executing:  88%|████████▊ | 7/8 [01:21<00:12, 12.04s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.16s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.17s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.24s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.27s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.25s/cell]
# Executing:  12%|█▎        | 1/8 [00:01<00:08,  1.21s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.24s/cell]
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.25s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.10s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.00s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.14s/cell]
# run archilochus_colubris
# run elanoides_forficatus
# run vireo_flavifrons
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.07s/cell]
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.11s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.21s/cell]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# run buteo_lineatus
# run setophaga_dominica
# run setophaga_citrina
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.26s/cell]
# Executing:  75%|███████▌  | 6/8 [00:01<00:00,  6.54cell/s]metadata: 1: cells: not found
# Executing:  12%|█▎        | 1/8 [00:01<00:07,  1.08s/cell]
# run dryocopus_pileatus
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.11s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.12s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.16s/cell]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# run meleagris_gallopavo
# run sphyrapicus_varius
# run odocoileus_virginianus
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.06s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.12s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.18s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.06s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.09s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.03s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.13s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.18s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.11s/cell]
# Executing:  12%|█▎        | 1/8 [00:01<00:08,  1.19s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.14s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.10s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.04s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.16s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.15s/cell]
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.19s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.15s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.23s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.15s/cell]
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.15s/cell]
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.16s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.09s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.05s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.06s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.07s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:21<00:00, 10.13s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.06s/cell]
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.04s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.04s/cell]
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.04s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:20<00:00, 10.06s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.62s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run ursus_americanus
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.68s/cell]
# metadata: 1: cells: not found
# Executing:  88%|████████▊ | 7/8 [01:24<00:12, 12.63s/cell]
# run anaxyrus_americanus
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.72s/cell]
# metadata: 1: cells: not found
# Executing:  88%|████████▊ | 7/8 [01:24<00:16, 16.85s/cell]
# run anaxyrus_fowleri
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.69s/cell]
# metadata: 1: cells: not found
# Executing:  75%|███████▌  | 6/8 [00:01<00:00,  5.90cell/s]
# run gastrophryne_carolinensis
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.68s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.68s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run hyla_avivoca
# run hyla_chrysoscelis
# Executing: 100%|██████████| 8/8 [01:26<00:00, 10.76s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:26<00:00, 10.78s/cell]
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.74s/cell]
# Executing:  12%|█▎        | 1/8 [00:01<00:08,  1.21s/cell]metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:26<00:00, 10.76s/cell]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run hyla_cinerea
# run hyla_squirella
# run hyla_versicolor
# run lithobates_catesbeianus
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.64s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.57s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.65s/cell]
# Executing:  88%|████████▊ | 7/8 [01:24<00:12, 12.53s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.65s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.63s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.67s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.65s/cell]
# Executing:  12%|█▎        | 1/8 [00:01<00:08,  1.20s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.70s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.69s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:26<00:00, 10.76s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.62s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.64s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.58s/cell]
# Executing:  75%|███████▌  | 6/8 [00:01<00:00,  6.54cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.58s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.56s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.60s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.52s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.65s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.59s/cell]
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.66s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.56s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.59s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.60s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:25<00:00, 10.65s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.52s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.57s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.59s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.58s/cell]
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.55s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.57s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.31s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run lithobates_clamitans
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.46s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run lithobates_palustris
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.42s/cell]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# run lithobates_sphenocephalus
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.48s/cell]
# Executing:  50%|█████     | 4/8 [00:01<00:01,  2.07cell/s]
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:24<00:00, 10.51s/cell]
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.44s/cell]
# run pseudacris_crucifer
# run pseudacris_fouquettei
# run kinosternon_subrubrum
# run apalone_spinifera
# run macrochelys_temmincki
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.47s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:22<00:00, 10.33s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.41s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [01:23<00:00, 10.45s/cell]
# metadata: 1: cells: not found
# Executing:  50%|█████     | 4/8 [00:01<00:01,  2.48cell/s]
# Executing: 100%|██████████| 8/8 [00:58<00:00,  7.36s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:58<00:00,  7.25s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.19s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.22s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:59<00:00,  7.39s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:59<00:00,  7.41s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:55<00:00,  6.97s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.10s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.13s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.19s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:55<00:00,  6.99s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.02s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.12s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.14s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.16s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.18s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.12s/cell]
# Executing: 100%|██████████| 8/8 [00:57<00:00,  7.17s/cell]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.09s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:55<00:00,  6.98s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.11s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.02s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.08s/cell]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 8/8 [00:56<00:00,  7.10s/cell]
# metadata: 1: cells: not found

# %%
print('## Failed species ##')
print('')
for i, result in enumerate(completed):
    if result[2] == 'fail':
        print(result[0], result[1])
# Out:
# ## Failed species ##
#
# lithobates_palustris winter
# macrochelys_temmincki winter
