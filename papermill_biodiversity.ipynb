# %%
import papermill as pm
import duckdb, subprocess, os, time
from joblib import Parallel, delayed

# %%
species_list = [
    "Protonotaria citrea",
    "Limnothlypis swainsonii",
    "Setophaga americana",
    "Empidonax virescens",
    "Coccyzus americanus",
    "Vireo griseus",
    "Setophaga cerulea",
    "Hylocichla mustelina",
    "Parkesia motacilla",
    "Geothlypis formosa",
    "Archilochus colubris",
    "Elanoides forficatus",
    "Vireo flavifrons",
    "Buteo lineatus",
    "Setophaga dominica",
    "Setophaga citrina",
    "Dryocopus pileatus",
    "Meleagris gallopavo",
    "Sphyrapicus varius",
    "Odocoileus virginianus",     # white tailed deer
    "Ursus americanus",           # Black bear
    "Anaxyrus americanus",        # American Toad
    "Anaxyrus fowleri",           # Fowler's Toad
    "Gastrophryne carolinensis",  # Eastern Narrow-mouthed Toad
    "Hyla avivoca",               # Bird-voiced Treefrog
    "Hyla chrysoscelis",          # Cope's Gray Treefrog
    "Hyla cinerea",               # Green Treefrog
    "Hyla squirella",             # Squirrel Treefrog    
    "Hyla versicolor",            # Gray Treefrog
    "Lithobates catesbeianus",    # American Bullfrog
    "Lithobates clamitans",       # Bronze Frog
    "Lithobates palustris",       # Pickerel Frog
    "Lithobates sphenocephalus",  # Southern Leopard Frog
    "Pseudacris crucifer",        # Spring Peeper
    "Pseudacris fouquettei",      # Cajun Chorus Frog
    "Kinosternon subrubrum",      # Eastern Mud Turtle
    "Apalone spinifera",          # Spiny Softshell Turtle   
    "Macrochelys temmincki"       # Alligator Snapping Turtle    
    ]
paramdir = '/mnt/d/readyparams/param_csvs'
outputdir = '/mnt/d/readyparams/ppp_paramsoutput'
jobs = 10
os.makedirs(outputdir, exist_ok=True)

# %%
species_list = [s.replace(" ", "_").lower() for s in species_list]
def f(x):
    try:
        spoutputdir = os.path.join(outputdir,x)
        os.makedirs(spoutputdir, exist_ok=True)        
        print('run',x)
        if jobs >1:
            subprocess.run(pm.execute_notebook(f'ppp_model.ipynb',os.path.join(spoutputdir,'{0}.ipynb'.format(x)),parameters=dict(parambasedir=paramdir, baseoutputdir=spoutputdir, sp=x)), shell=True)
        else:
            pm.execute_notebook(f'ppp_model.ipynb',os.path.join(spoutputdir,'{0}.ipynb'.format(x)),parameters=dict(parambasedir=paramdir, baseoutputdir=spoutputdir, sp=x))
        return (x, 'run complete')
    except Exception as e:
        return (x,'fail', e)

# %%
completed = Parallel(n_jobs=10, verbose=0)(delayed(f)(species_list[x]) for x in range(len(species_list)))
# Out:
# run limnothlypis_swainsonii
# run protonotaria_citrea
# run setophaga_americana
# run empidonax_virescens
# run coccyzus_americanus
# run vireo_griseus
# run setophaga_cerulea
# run hylocichla_mustelina
# run parkesia_motacilla
# run geothlypis_formosa
# Executing: 100%|██████████| 18/18 [00:07<00:00,  2.26cell/s]
# metadata: 1: cells: not found
# Executing:  56%|█████▌    | 10/18 [00:08<00:09,  1.22s/cell]
# run archilochus_colubris
# Executing: 100%|██████████| 18/18 [00:08<00:00,  2.12cell/s]
# Executing:  78%|███████▊  | 14/18 [00:08<00:02,  1.57cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run elanoides_forficatus
# Executing: 100%|██████████| 18/18 [00:08<00:00,  2.07cell/s]
# Executing: 100%|██████████| 18/18 [00:08<00:00,  2.07cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run vireo_flavifrons
# run buteo_lineatus
# Executing: 100%|██████████| 18/18 [00:09<00:00,  1.85cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run setophaga_dominica
# Executing: 100%|██████████| 18/18 [00:10<00:00,  1.75cell/s]
# Executing: 100%|██████████| 18/18 [00:10<00:00,  1.75cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]9cell/s]
# run setophaga_citrina
# run dryocopus_pileatus
# run meleagris_gallopavo
# Executing: 100%|██████████| 18/18 [00:10<00:00,  1.72cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:10<00:00,  1.70cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run sphyrapicus_varius
# Executing: 100%|██████████| 18/18 [00:11<00:00,  1.58cell/s]
# metadata: 1: cells: not found
# Executing:  44%|████▍     | 8/18 [00:02<00:02,  3.60cell/s]
# run odocoileus_virginianus
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.88cell/s]
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.76cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:07<00:00,  2.56cell/s]
# Executing:  72%|███████▏  | 13/18 [00:04<00:01,  3.51cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run ursus_americanus
# run anaxyrus_americanus
# run anaxyrus_fowleri
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.60cell/s]
# metadata: 1: cells: not found
# Executing:  61%|██████    | 11/18 [00:04<00:02,  2.94cell/s]
# run gastrophryne_carolinensis
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.71cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run hyla_avivoca
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.78cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.81cell/s]
# metadata: 1: cells: not found
# Executing:   6%|▌         | 1/18 [00:01<00:32,  1.89s/cell]]
# run hyla_chrysoscelis
# run hyla_cinerea
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.70cell/s]
# Executing: 100%|██████████| 18/18 [00:06<00:00,  4.52cell/s]metadata: 1: cells: not found
# Executing:  28%|██▊       | 5/18 [00:02<00:04,  3.08cell/s]]
# run hyla_squirella
# Executing: 100%|██████████| 18/18 [00:07<00:00,  2.52cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.80cell/s]
# Executing:  39%|███▉      | 7/18 [00:02<00:03,  3.05cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run hyla_versicolor
# run lithobates_catesbeianus
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.16cell/s]
# Executing:  61%|██████    | 11/18 [00:03<00:01,  3.51cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.06cell/s]
# Executing:  39%|███▉      | 7/18 [00:03<00:03,  2.92cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run lithobates_clamitans
# run lithobates_palustris
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.01cell/s]
# Executing:  72%|███████▏  | 13/18 [00:04<00:01,  4.34cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]30cell/s]
# run lithobates_sphenocephalus
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.91cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.18cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run pseudacris_crucifer
# run pseudacris_fouquettei
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.91cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.88cell/s]
# Executing:   6%|▌         | 1/18 [00:02<00:37,  2.21s/cell]metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run kinosternon_subrubrum
# run apalone_spinifera
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.18cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# run macrochelys_temmincki
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.17cell/s]
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.76cell/s]
# Executing:  39%|███▉      | 7/18 [00:02<00:03,  3.12cell/s]metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing:  28%|██▊       | 5/18 [00:03<00:08,  1.57cell/s]
# Executing:  28%|██▊       | 5/18 [00:02<00:07,  1.71cell/s]]
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.94cell/s]
# Executing: 100%|██████████| 18/18 [00:04<00:00,  5.72cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:06<00:00,  2.96cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.33cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.27cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.31cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 18/18 [00:05<00:00,  3.15cell/s]
# metadata: 1: cells: not found

# %%
print('## Failed species ##')
print('')
for i, result in enumerate(completed):
    if result[1] == 'fail':
        print(result[0])
# Out:
# ## Failed species ##
#
# lithobates_palustris
# macrochelys_temmincki
