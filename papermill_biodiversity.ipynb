# %%
import papermill as pm
import duckdb, subprocess, os, time
from joblib import Parallel, delayed

# %%
species_list = [
    "Protonotaria citrea",
    "Limnothlypis swainsonii",
    "Setophaga americana",
    "Empidonax virescens",
    "Coccyzus americanus",
    "Vireo griseus",
    "Setophaga cerulea",
    "Hylocichla mustelina",
    "Parkesia motacilla",
    "Geothlypis formosa",
    "Archilochus colubris",
    "Elanoides forficatus",
    "Vireo flavifrons",
    "Buteo lineatus",
    "Setophaga dominica",
    "Setophaga citrina",
    "Dryocopus pileatus",
    "Meleagris gallopavo",
    "Sphyrapicus varius",
    "Odocoileus virginianus",     # white tailed deer
    "Ursus americanus",           # Black bear
    "Anaxyrus americanus",        # American Toad
    "Anaxyrus fowleri",           # Fowler's Toad
    "Gastrophryne carolinensis",  # Eastern Narrow-mouthed Toad
    "Hyla avivoca",               # Bird-voiced Treefrog
    "Hyla chrysoscelis",          # Cope's Gray Treefrog
    "Hyla cinerea",               # Green Treefrog
    "Hyla squirella",             # Squirrel Treefrog    
    "Hyla versicolor",            # Gray Treefrog
    "Lithobates catesbeianus",    # American Bullfrog
    "Lithobates clamitans",       # Bronze Frog
    "Lithobates palustris",       # Pickerel Frog
    "Lithobates sphenocephalus",  # Southern Leopard Frog
    "Pseudacris crucifer",        # Spring Peeper
    "Pseudacris fouquettei",      # Cajun Chorus Frog
    "Kinosternon subrubrum",      # Eastern Mud Turtle
    "Apalone spinifera",          # Spiny Softshell Turtle   
    "Macrochelys temmincki"       # Alligator Snapping Turtle    
    ]
paramdir = '/mnt/d/readyparams/param_csvs'
outputdir = '/mnt/d/readyparams/ppp_paramsoutput'
jobs = 10
os.makedirs(outputdir, exist_ok=True)

# %%
species_list = [s.replace(" ", "_").lower() for s in species_list]
def f(x):
    try:
        spoutputdir = os.path.join(outputdir,x)
        os.makedirs(spoutputdir, exist_ok=True)        
        print('run',x)
        if jobs >1:
            subprocess.run(pm.execute_notebook(f'ppp_model.ipynb',os.path.join(spoutputdir,'{0}.ipynb'.format(x)),parameters=dict(parambasedir=paramdir, baseoutputdir=spoutputdir, sp=x)), shell=True)
        else:
            pm.execute_notebook(f'ppp_model.ipynb',os.path.join(spoutputdir,'{0}.ipynb'.format(x)),parameters=dict(parambasedir=paramdir, baseoutputdir=spoutputdir, sp=x))
        return (x, 'run complete')
    except Exception as e:
        return (x,'fail', e)

# %%
completed = Parallel(n_jobs=10, verbose=0)(delayed(f)(species_list[x]) for x in range(len(species_list)))
# Out:
# run empidonax_virescens
# run limnothlypis_swainsonii
# run hylocichla_mustelina
# run setophaga_cerulea
# run geothlypis_formosa
# run parkesia_motacilla
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# run setophaga_americana
# run vireo_griseus
# run protonotaria_citrea
# run coccyzus_americanus
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.96cell/s]
# Executing:  59%|█████▉    | 10/17 [00:05<00:03,  1.76cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]70cell/s]
# run archilochus_colubris
# run elanoides_forficatus
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.87cell/s]
# Executing:  76%|███████▋  | 13/17 [00:05<00:01,  2.61cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.80cell/s]
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.79cell/s]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# run vireo_flavifrons
# run buteo_lineatus
# Executing: 100%|██████████| 17/17 [00:07<00:00,  2.38cell/s]
# Executing:  94%|█████████▍| 16/17 [00:06<00:00,  3.76cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:07<00:00,  2.34cell/s]
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.45cell/s]
# metadata: 1: cells: not found
# Executing:  65%|██████▍   | 11/17 [00:06<00:04,  1.31cell/s]
# run setophaga_dominica
# run setophaga_citrina
# run dryocopus_pileatus
# Executing: 100%|██████████| 17/17 [00:07<00:00,  2.27cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:07<00:00,  2.31cell/s]
# metadata: 1: cells: not found
# Executing:   6%|▌         | 1/17 [00:01<00:28,  1.81s/cell]]
# run meleagris_gallopavo
# run sphyrapicus_varius
# Executing: 100%|██████████| 17/17 [00:08<00:00,  2.07cell/s]
# metadata: 1: cells: not found
# Executing:  41%|████      | 7/17 [00:02<00:03,  3.14cell/s]
# run odocoileus_virginianus
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.42cell/s]
# Executing:  82%|████████▏ | 14/17 [00:04<00:01,  2.95cell/s]metadata: 1: cells: not found
# Executing:  76%|███████▋  | 13/17 [00:03<00:00,  4.50cell/s]
# run ursus_americanus
# run anaxyrus_americanus
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.23cell/s]
# Executing:  59%|█████▉    | 10/17 [00:03<00:01,  4.05cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.85cell/s]
# Executing:  94%|█████████▍| 16/17 [00:04<00:00,  5.10cell/s]metadata: 1: cells: not found
# Executing:  41%|████      | 7/17 [00:03<00:03,  2.75cell/s]]
# run anaxyrus_fowleri
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.89cell/s]
# metadata: 1: cells: not found
# Executing:  94%|█████████▍| 16/17 [00:04<00:00,  4.68cell/s]
# run gastrophryne_carolinensis
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.28cell/s]
# metadata: 1: cells: not found
# Executing:  82%|████████▏ | 14/17 [00:05<00:00,  3.09cell/s]
# run hyla_avivoca
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.98cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# run hyla_chrysoscelis
# run hyla_cinerea
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.25cell/s]
# Executing: 100%|██████████| 17/17 [00:05<00:00,  5.53cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.79cell/s]
# metadata: 1: cells: not found
# Executing:  29%|██▉       | 5/17 [00:02<00:04,  2.96cell/s]
# run hyla_squirella
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.93cell/s]
# Executing:  88%|████████▊ | 15/17 [00:04<00:00,  4.02cell/s]metadata: 1: cells: not found
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# run hyla_versicolor
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.81cell/s]
# Executing:  41%|████      | 7/17 [00:02<00:03,  3.20cell/s]metadata: 1: cells: not found
# Executing:   6%|▌         | 1/17 [00:01<00:30,  1.89s/cell]]
# run lithobates_catesbeianus
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.39cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.45cell/s]
# Executing:  82%|████████▏ | 14/17 [00:04<00:00,  4.06cell/s]metadata: 1: cells: not found
# Executing:  94%|█████████▍| 16/17 [00:04<00:00,  5.70cell/s]
# run lithobates_clamitans
# run lithobates_palustris
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.44cell/s]
# Executing:  71%|███████   | 12/17 [00:03<00:00,  6.11cell/s]metadata: 1: cells: not found
# Executing:  76%|███████▋  | 13/17 [00:04<00:00,  4.37cell/s]
# run lithobates_sphenocephalus
# Executing: 100%|██████████| 17/17 [00:05<00:00,  2.96cell/s]
# Executing:  65%|██████▍   | 11/17 [00:04<00:01,  3.36cell/s]metadata: 1: cells: not found
# Executing:  88%|████████▊ | 15/17 [00:04<00:00,  3.99cell/s]
# run pseudacris_crucifer
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.21cell/s]
# metadata: 1: cells: not found
# Executing:  76%|███████▋  | 13/17 [00:04<00:00,  4.11cell/s]
# run pseudacris_fouquettei
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.19cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.02cell/s]
# run kinosternon_subrubrum
# run apalone_spinifera
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.48cell/s]
# metadata: 1: cells: not found
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# run macrochelys_temmincki
# Executing:  29%|██▉       | 5/17 [00:03<00:07,  1.55cell/s]]
# Executing: 100%|██████████| 17/17 [00:06<00:00,  2.80cell/s]
# Executing:   6%|▌         | 1/17 [00:01<00:31,  1.96s/cell]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.19cell/s]
# Executing:  76%|███████▋  | 13/17 [00:04<00:00,  4.21cell/s]metadata: 1: cells: not found
# Executing:  29%|██▉       | 5/17 [00:02<00:06,  1.76cell/s]]
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.17cell/s]
# Executing:  82%|████████▏ | 14/17 [00:03<00:00,  4.39cell/s]metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:05<00:00,  3.31cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.61cell/s]
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.78cell/s]
# metadata: 1: cells: not found
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.72cell/s]
# metadata: 1: cells: not found
# Executing: 100%|██████████| 17/17 [00:04<00:00,  3.58cell/s]
# metadata: 1: cells: not found

# %%
print('## Failed species ##')
print('')
for i, result in enumerate(completed):
    if result[1] == 'fail':
        print(result[0])
# Out:
# ## Failed ##
#
# lithobates_palustris
# macrochelys_temmincki
